# %%
import cv2
from ultralytics import YOLO
import os
from paddleocr import PaddleOCR, draw_ocr

class LicensePlateProcessor:
    def __init__(self, model_path):
        self.model = YOLO(model_path)
        self.ocr = PaddleOCR(use_angle_cls=True, lang='en')
    
    def detect_and_recognize(self, image_path, output_folder):
        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Failed to read image: {image_path}")
            return None, "No text detected"

        # Run inference to detect license plate
        results = self.model(image)
        boxes = results[0].boxes

        if boxes is None or len(boxes) == 0:
            print(f"No license plate detected in {image_path}.")
            return None, "No text detected"

        highest_conf_box = None
        highest_conf_score = 0

        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0] 
            confidence = box.conf[0]  
            cls = box.cls[0] 
            
            if int(cls) == 0: 
                if confidence > highest_conf_score:
                    highest_conf_box = {'x1': int(x1), 'y1': int(y1), 'x2': int(x2), 'y2': int(y2), 'confidence': confidence}
                    highest_conf_score = confidence
        
        # If a license plate was detected, crop it from the image
        if highest_conf_box is not None:
            x1, y1, x2, y2 = highest_conf_box['x1'], highest_conf_box['y1'], highest_conf_box['x2'], highest_conf_box['y2']
            cropped_plate = image[y1:y2, x1:x2]
            
            # Save cropped plate to output folder
            cropped_output_path = os.path.join(output_folder, f"cropped_{os.path.basename(image_path)}")
            os.makedirs(output_folder, exist_ok=True)
            cv2.imwrite(cropped_output_path, cropped_plate)

            # Perform OCR on the cropped license plate
            ocr_results = self.ocr.ocr(cropped_output_path, cls=True)
            
            # Default detected text
            detected_text = "No text detected"

            # Check if OCR results are valid
            if ocr_results and isinstance(ocr_results, list) and len(ocr_results) > 0 and ocr_results[0]:
                detected_text = " ".join([line[1][0] for line in ocr_results[0]])

            # Write detected text on the image
            cv2.putText(image, detected_text.strip(), (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
            
            # Draw the bounding box on the image
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # Save the annotated image
            annotated_image_path = os.path.join(output_folder, f"annotated_{os.path.basename(image_path)}")
            cv2.imwrite(annotated_image_path, image)
            
            print(f"Annotated image saved at {annotated_image_path}")
            print(f"Detected text: {detected_text.strip()}")
            return highest_conf_box, detected_text.strip()
        
        print(f"No valid license plate detected in {image_path}.")
        return None, "No text detected"


# Example usage
model_path = '/media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/best.pt'  # Specify the path to your YOLOv8 model
processor = LicensePlateProcessor(model_path)

# Folder containing license plate images
image_folder = '/media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/test_images'  # Replace with the path to your folder
output_folder = '/media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image'    # Replace with the desired output folder

for image_file in os.listdir(image_folder):
    image_path = os.path.join(image_folder, image_file)
    if os.path.isfile(image_path):
        bbox, detected_text = processor.detect_and_recognize(image_path, output_folder)
        print(f"Processed: {image_file}")
        print("Bounding box:", bbox)
        print("Detected text:", detected_text)
# Out:
# [2024/11/18 20:06:10] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/asmany/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/asmany/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='/home/asmany/.local/lib/python3.10/site-packages/paddleocr/ppocr/utils/en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='/home/asmany/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# 0: 640x640 (no detections), 75.2ms
# Speed: 4.0ms preprocess, 75.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# No license plate detected in /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/test_images/5daafbcf76fa6602_jpg.rf.14442dd74aa0e629fe892e73fb65e71f_fog.jpg.
# Processed: 5daafbcf76fa6602_jpg.rf.14442dd74aa0e629fe892e73fb65e71f_fog.jpg
# Bounding box: None
# Detected text: No text detected
#
# 0: 640x640 1 license_plate, 71.8ms
# Speed: 2.8ms preprocess, 71.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:11] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.02639007568359375
# [2024/11/18 20:06:11] ppocr DEBUG: cls num  : 1, elapsed : 0.015416860580444336
# [2024/11/18 20:06:11] ppocr DEBUG: rec_res num  : 1, elapsed : 0.14766311645507812
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_OUP1442_rain.jpg
# Detected text: OUP1442
# Processed: OUP1442_rain.jpg
# Bounding box: {'x1': 622, 'y1': 719, 'x2': 840, 'y2': 784, 'confidence': tensor(0.8485)}
# Detected text: OUP1442
#
# 0: 448x640 1 license_plate, 52.0ms
# Speed: 2.5ms preprocess, 52.0ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:12] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.014474630355834961
# [2024/11/18 20:06:12] ppocr DEBUG: cls num  : 1, elapsed : 0.013049125671386719
# [2024/11/18 20:06:12] ppocr DEBUG: rec_res num  : 1, elapsed : 0.13469767570495605
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_f73b754cdb1ab677_shadow.jpg
# Detected text: UN29526
# Processed: f73b754cdb1ab677_shadow.jpg
# Bounding box: {'x1': 681, 'y1': 517, 'x2': 844, 'y2': 554, 'confidence': tensor(0.8109)}
# Detected text: UN29526
#
# 0: 448x640 1 license_plate, 48.1ms
# Speed: 2.1ms preprocess, 48.1ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:12] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.013781547546386719
# [2024/11/18 20:06:12] ppocr DEBUG: cls num  : 1, elapsed : 0.011384725570678711
# [2024/11/18 20:06:12] ppocr DEBUG: rec_res num  : 1, elapsed : 0.13657784461975098
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_74ee6d1b58ae2e70.jpg
# Detected text: KAKAO.LV
# Processed: 74ee6d1b58ae2e70.jpg
# Bounding box: {'x1': 430, 'y1': 386, 'x2': 598, 'y2': 425, 'confidence': tensor(0.7999)}
# Detected text: KAKAO.LV
#
# 0: 640x640 1 license_plate, 72.2ms
# Speed: 2.2ms preprocess, 72.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:12] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.036168813705444336
# [2024/11/18 20:06:12] ppocr DEBUG: cls num  : 2, elapsed : 0.015103816986083984
# [2024/11/18 20:06:12] ppocr DEBUG: rec_res num  : 2, elapsed : 0.27922725677490234
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_NZU2673.jpg
# Detected text: BA-SALVADOR NZU-2673
# Processed: NZU2673.jpg
# Bounding box: {'x1': 493, 'y1': 820, 'x2': 780, 'y2': 906, 'confidence': tensor(0.9013)}
# Detected text: BA-SALVADOR NZU-2673
#
# 0: 320x640 1 license_plate, 38.7ms
# Speed: 2.8ms preprocess, 38.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# [2024/11/18 20:06:12] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.011683225631713867
# [2024/11/18 20:06:12] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2024/11/18 20:06:12] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_03fe4b804d6f46c6_fog.jpg
# Detected text: No text detected
# Processed: 03fe4b804d6f46c6_fog.jpg
# Bounding box: {'x1': 796, 'y1': 217, 'x2': 909, 'y2': 259, 'confidence': tensor(0.7092)}
# Detected text: No text detected
#
# 0: 480x640 1 license_plate, 63.5ms
# Speed: 2.1ms preprocess, 63.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:13] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.012093782424926758
# [2024/11/18 20:06:13] ppocr DEBUG: cls num  : 1, elapsed : 0.009352684020996094
# [2024/11/18 20:06:13] ppocr DEBUG: rec_res num  : 1, elapsed : 0.12648534774780273
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_064_shadow.jpg
# Detected text: BZM:22-27
# Processed: test_064_shadow.jpg
# Bounding box: {'x1': 156, 'y1': 142, 'x2': 268, 'y2': 168, 'confidence': tensor(0.8893)}
# Detected text: BZM:22-27
#
# 0: 480x640 1 license_plate, 78.8ms
# Speed: 6.1ms preprocess, 78.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:13] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01284170150756836
# [2024/11/18 20:06:13] ppocr DEBUG: cls num  : 1, elapsed : 0.010545015335083008
# [2024/11/18 20:06:13] ppocr DEBUG: rec_res num  : 1, elapsed : 0.12337398529052734
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_eu2.jpg
# Detected text: GWAGEN
# Processed: eu2.jpg
# Bounding box: {'x1': 139, 'y1': 260, 'x2': 281, 'y2': 288, 'confidence': tensor(0.8540)}
# Detected text: GWAGEN
#
# 0: 480x640 1 license_plate, 55.3ms
# Speed: 2.2ms preprocess, 55.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:13] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.041822195053100586
# [2024/11/18 20:06:13] ppocr DEBUG: cls num  : 2, elapsed : 0.016424894332885742
# [2024/11/18 20:06:13] ppocr DEBUG: rec_res num  : 2, elapsed : 0.23805856704711914
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_d8daed582e6cce2d.jpg
# Detected text: FD-1475 haoss.lv
# Processed: d8daed582e6cce2d.jpg
# Bounding box: {'x1': 495, 'y1': 340, 'x2': 745, 'y2': 482, 'confidence': tensor(0.8661)}
# Detected text: FD-1475 haoss.lv
#
# 0: 480x640 1 license_plate, 55.6ms
# Speed: 3.7ms preprocess, 55.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:13] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.014344215393066406
# [2024/11/18 20:06:13] ppocr DEBUG: cls num  : 1, elapsed : 0.014482975006103516
# [2024/11/18 20:06:14] ppocr DEBUG: rec_res num  : 1, elapsed : 0.12364339828491211
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_077_shadow.jpg
# Detected text: RK-735AS
# Processed: test_077_shadow.jpg
# Bounding box: {'x1': 176, 'y1': 227, 'x2': 285, 'y2': 252, 'confidence': tensor(0.8771)}
# Detected text: RK-735AS
#
# 0: 640x640 1 license_plate, 77.6ms
# Speed: 4.5ms preprocess, 77.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:14] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.02126026153564453
# [2024/11/18 20:06:14] ppocr DEBUG: cls num  : 1, elapsed : 0.009609460830688477
# [2024/11/18 20:06:14] ppocr DEBUG: rec_res num  : 1, elapsed : 0.11971235275268555
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_OUG6157_shadow.jpg
# Detected text: OUG-6157
# Processed: OUG6157_shadow.jpg
# Bounding box: {'x1': 613, 'y1': 547, 'x2': 831, 'y2': 624, 'confidence': tensor(0.8657)}
# Detected text: OUG-6157
#
# 0: 640x640 1 license_plate, 81.3ms
# Speed: 2.4ms preprocess, 81.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:14] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.008890628814697266
# [2024/11/18 20:06:14] ppocr DEBUG: cls num  : 1, elapsed : 0.009645223617553711
# [2024/11/18 20:06:14] ppocr DEBUG: rec_res num  : 1, elapsed : 0.11971378326416016
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_5290f4027491d09b_jpg.rf.3f3b30829f571d5321712f126e797f07_rain.jpg
# Detected text: 27-8N42
# Processed: 5290f4027491d09b_jpg.rf.3f3b30829f571d5321712f126e797f07_rain.jpg
# Bounding box: {'x1': 64, 'y1': 295, 'x2': 138, 'y2': 327, 'confidence': tensor(0.7508)}
# Detected text: 27-8N42
#
# 0: 480x640 1 license_plate, 58.3ms
# Speed: 2.1ms preprocess, 58.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:14] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.011603832244873047
# [2024/11/18 20:06:14] ppocr DEBUG: cls num  : 1, elapsed : 0.008810043334960938
# [2024/11/18 20:06:14] ppocr DEBUG: rec_res num  : 1, elapsed : 0.12073445320129395
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_040_rain.jpg
# Detected text: RK-TOTAL
# Processed: test_040_rain.jpg
# Bounding box: {'x1': 305, 'y1': 267, 'x2': 411, 'y2': 295, 'confidence': tensor(0.8225)}
# Detected text: RK-TOTAL
#
# 0: 480x640 1 license_plate, 60.3ms
# Speed: 2.7ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:14] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.023096799850463867
# [2024/11/18 20:06:14] ppocr DEBUG: cls num  : 2, elapsed : 0.016640424728393555
# [2024/11/18 20:06:15] ppocr DEBUG: rec_res num  : 2, elapsed : 0.5220611095428467
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_7de85d97fce5c049.jpg
# Detected text: BH35-BV NEW SOUTH WALES
# Processed: 7de85d97fce5c049.jpg
# Bounding box: {'x1': 434, 'y1': 420, 'x2': 646, 'y2': 500, 'confidence': tensor(0.8428)}
# Detected text: BH35-BV NEW SOUTH WALES
#
# 0: 480x640 1 license_plate, 55.8ms
# Speed: 2.4ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:15] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.035985708236694336
# [2024/11/18 20:06:15] ppocr DEBUG: cls num  : 2, elapsed : 0.01633596420288086
# [2024/11/18 20:06:15] ppocr DEBUG: rec_res num  : 2, elapsed : 0.2812056541442871
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_80e02a518ffe4cb2_shadow.jpg
# Detected text: B 81 JKY RO
# Processed: 80e02a518ffe4cb2_shadow.jpg
# Bounding box: {'x1': 375, 'y1': 432, 'x2': 673, 'y2': 505, 'confidence': tensor(0.8661)}
# Detected text: B 81 JKY RO
#
# 0: 480x640 1 license_plate, 52.3ms
# Speed: 1.8ms preprocess, 52.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:15] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.014332294464111328
# [2024/11/18 20:06:15] ppocr DEBUG: cls num  : 1, elapsed : 0.010122060775756836
# [2024/11/18 20:06:16] ppocr DEBUG: rec_res num  : 1, elapsed : 0.15406250953674316
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_006_shadow.jpg
# Detected text: RK-099AN
# Processed: test_006_shadow.jpg
# Bounding box: {'x1': 205, 'y1': 269, 'x2': 356, 'y2': 304, 'confidence': tensor(0.8923)}
# Detected text: RK-099AN
#
# 0: 640x448 1 license_plate, 75.5ms
# Speed: 2.3ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# [2024/11/18 20:06:16] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.024685144424438477
# [2024/11/18 20:06:16] ppocr DEBUG: cls num  : 1, elapsed : 0.010915279388427734
# [2024/11/18 20:06:16] ppocr DEBUG: rec_res num  : 1, elapsed : 0.14572691917419434
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_faa74a34d48ea979.jpg
# Detected text: MAK1401
# Processed: faa74a34d48ea979.jpg
# Bounding box: {'x1': 419, 'y1': 820, 'x2': 608, 'y2': 869, 'confidence': tensor(0.8288)}
# Detected text: MAK1401
#
# 0: 640x640 1 license_plate, 83.0ms
# Speed: 2.4ms preprocess, 83.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:16] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.011533975601196289
# [2024/11/18 20:06:16] ppocr DEBUG: cls num  : 1, elapsed : 0.010499000549316406
# [2024/11/18 20:06:16] ppocr DEBUG: rec_res num  : 1, elapsed : 0.13338565826416016
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_d3729058c6a4186e_jpg.rf.7b93b9b84f702138e29c507a88bcdcf8.jpg
# Detected text: 3646 HBH
# Processed: d3729058c6a4186e_jpg.rf.7b93b9b84f702138e29c507a88bcdcf8.jpg
# Bounding box: {'x1': 236, 'y1': 196, 'x2': 300, 'y2': 228, 'confidence': tensor(0.7750)}
# Detected text: 3646 HBH
#
# 0: 384x640 1 license_plate, 59.9ms
# Speed: 1.5ms preprocess, 59.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [2024/11/18 20:06:16] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.03446507453918457
# [2024/11/18 20:06:16] ppocr DEBUG: cls num  : 1, elapsed : 0.010642766952514648
# [2024/11/18 20:06:16] ppocr DEBUG: rec_res num  : 1, elapsed : 0.13512325286865234
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_OLC4728_fog.jpg
# Detected text: OLC-4728
# Processed: OLC4728_fog.jpg
# Bounding box: {'x1': 514, 'y1': 410, 'x2': 792, 'y2': 492, 'confidence': tensor(0.8719)}
# Detected text: OLC-4728
#
# 0: 480x640 1 license_plate, 57.3ms
# Speed: 2.2ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:17] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.021624326705932617
# [2024/11/18 20:06:17] ppocr DEBUG: cls num  : 1, elapsed : 0.009907960891723633
# [2024/11/18 20:06:17] ppocr DEBUG: rec_res num  : 1, elapsed : 0.13463592529296875
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_7c55ec3a29141fcd_fog.jpg
# Detected text: UCH456
# Processed: 7c55ec3a29141fcd_fog.jpg
# Bounding box: {'x1': 137, 'y1': 378, 'x2': 286, 'y2': 479, 'confidence': tensor(0.6858)}
# Detected text: UCH456
#
# 0: 480x640 1 license_plate, 54.5ms
# Speed: 1.7ms preprocess, 54.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:17] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.012746334075927734
# [2024/11/18 20:06:17] ppocr DEBUG: cls num  : 1, elapsed : 0.009943962097167969
# [2024/11/18 20:06:17] ppocr DEBUG: rec_res num  : 1, elapsed : 0.14660406112670898
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_043_shadow.jpg
# Detected text: DK641AH
# Processed: test_043_shadow.jpg
# Bounding box: {'x1': 126, 'y1': 156, 'x2': 214, 'y2': 176, 'confidence': tensor(0.8658)}
# Detected text: DK641AH
#
# 0: 448x640 1 license_plate, 52.7ms
# Speed: 2.0ms preprocess, 52.7ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:17] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.026616573333740234
# [2024/11/18 20:06:17] ppocr DEBUG: cls num  : 1, elapsed : 0.009821891784667969
# [2024/11/18 20:06:17] ppocr DEBUG: rec_res num  : 1, elapsed : 0.1385042667388916
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_87793700161a7a6b_rain.jpg
# Detected text: BMW M5
# Processed: 87793700161a7a6b_rain.jpg
# Bounding box: {'x1': 449, 'y1': 455, 'x2': 724, 'y2': 521, 'confidence': tensor(0.8587)}
# Detected text: BMW M5
#
# 0: 448x640 1 license_plate, 50.8ms
# Speed: 3.4ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:17] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.020688533782958984
# [2024/11/18 20:06:17] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2024/11/18 20:06:17] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_76e14d05ee8acb6d_fog.jpg
# Detected text: No text detected
# Processed: 76e14d05ee8acb6d_fog.jpg
# Bounding box: {'x1': 105, 'y1': 297, 'x2': 254, 'y2': 399, 'confidence': tensor(0.6350)}
# Detected text: No text detected
#
# 0: 640x640 1 license_plate, 82.6ms
# Speed: 2.7ms preprocess, 82.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:17] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.02063918113708496
# [2024/11/18 20:06:17] ppocr DEBUG: cls num  : 1, elapsed : 0.009588956832885742
# [2024/11/18 20:06:18] ppocr DEBUG: rec_res num  : 1, elapsed : 0.14452433586120605
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_JRD2238.jpg
# Detected text: JRD-2238
# Processed: JRD2238.jpg
# Bounding box: {'x1': 416, 'y1': 598, 'x2': 567, 'y2': 648, 'confidence': tensor(0.7465)}
# Detected text: JRD-2238
#
# 0: 480x640 1 license_plate, 54.6ms
# Speed: 1.8ms preprocess, 54.6ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:18] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.008668184280395508
# [2024/11/18 20:06:18] ppocr DEBUG: cls num  : 1, elapsed : 0.011124610900878906
# [2024/11/18 20:06:18] ppocr DEBUG: rec_res num  : 1, elapsed : 0.1363842487335205
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_052_rain.jpg
# Detected text: 555494
# Processed: test_052_rain.jpg
# Bounding box: {'x1': 101, 'y1': 127, 'x2': 161, 'y2': 143, 'confidence': tensor(0.8040)}
# Detected text: 555494
#
# 0: 480x640 1 license_plate, 66.2ms
# Speed: 2.7ms preprocess, 66.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:18] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.027898788452148438
# [2024/11/18 20:06:18] ppocr DEBUG: cls num  : 1, elapsed : 0.015355110168457031
# [2024/11/18 20:06:18] ppocr DEBUG: rec_res num  : 1, elapsed : 0.14501643180847168
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_3d766b599eab8353_shadow.jpg
# Detected text: HP-02662
# Processed: 3d766b599eab8353_shadow.jpg
# Bounding box: {'x1': 568, 'y1': 536, 'x2': 801, 'y2': 596, 'confidence': tensor(0.7480)}
# Detected text: HP-02662
#
# 0: 480x640 1 license_plate, 53.3ms
# Speed: 2.3ms preprocess, 53.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:18] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.020632028579711914
# [2024/11/18 20:06:18] ppocr DEBUG: cls num  : 1, elapsed : 0.010616064071655273
# [2024/11/18 20:06:18] ppocr DEBUG: rec_res num  : 1, elapsed : 0.13397812843322754
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_895d440e05b2a8d8.jpg
# Detected text: 1277DPZ
# Processed: 895d440e05b2a8d8.jpg
# Bounding box: {'x1': 181, 'y1': 522, 'x2': 405, 'y2': 578, 'confidence': tensor(0.8217)}
# Detected text: 1277DPZ
#
# 0: 480x640 1 license_plate, 50.5ms
# Speed: 3.0ms preprocess, 50.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:18] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01390838623046875
# [2024/11/18 20:06:18] ppocr DEBUG: cls num  : 1, elapsed : 0.014461755752563477
# [2024/11/18 20:06:19] ppocr DEBUG: rec_res num  : 1, elapsed : 0.14559149742126465
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_e5edf93b7c9f5edb_fog.jpg
# Detected text: IN-A7506
# Processed: e5edf93b7c9f5edb_fog.jpg
# Bounding box: {'x1': 323, 'y1': 475, 'x2': 495, 'y2': 515, 'confidence': tensor(0.7634)}
# Detected text: IN-A7506
#
# 0: 640x640 1 license_plate, 81.1ms
# Speed: 2.5ms preprocess, 81.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:19] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.014091014862060547
# [2024/11/18 20:06:19] ppocr DEBUG: cls num  : 1, elapsed : 0.012129545211791992
# [2024/11/18 20:06:19] ppocr DEBUG: rec_res num  : 1, elapsed : 0.1410079002380371
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_b32671b7cc279583_jpg.rf.f898026e2169a3b6adc4d21aee6d06c5_rain.jpg
# Detected text: 208
# Processed: b32671b7cc279583_jpg.rf.f898026e2169a3b6adc4d21aee6d06c5_rain.jpg
# Bounding box: {'x1': 60, 'y1': 174, 'x2': 166, 'y2': 230, 'confidence': tensor(0.3383)}
# Detected text: 208
#
# 0: 480x640 1 license_plate, 58.7ms
# Speed: 1.9ms preprocess, 58.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:19] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.0211181640625
# [2024/11/18 20:06:19] ppocr DEBUG: cls num  : 2, elapsed : 0.019624710083007812
# [2024/11/18 20:06:19] ppocr DEBUG: rec_res num  : 2, elapsed : 0.2658650875091553
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_OYJ9557.jpg
# Detected text: ES-VILAVELHA OYJ-9557
# Processed: OYJ9557.jpg
# Bounding box: {'x1': 491, 'y1': 640, 'x2': 725, 'y2': 713, 'confidence': tensor(0.8606)}
# Detected text: ES-VILAVELHA OYJ-9557
#
# 0: 224x640 1 license_plate, 37.2ms
# Speed: 0.9ms preprocess, 37.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 640)
# [2024/11/18 20:06:19] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010904550552368164
# [2024/11/18 20:06:19] ppocr DEBUG: cls num  : 1, elapsed : 0.009716510772705078
# [2024/11/18 20:06:19] ppocr DEBUG: rec_res num  : 1, elapsed : 0.14161252975463867
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_042_rain.jpg
# Detected text: BA-2681
# Processed: test_042_rain.jpg
# Bounding box: {'x1': 232, 'y1': 130, 'x2': 333, 'y2': 154, 'confidence': tensor(0.7766)}
# Detected text: BA-2681
#
# 0: 384x640 1 license_plate, 82.3ms
# Speed: 2.0ms preprocess, 82.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [2024/11/18 20:06:20] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.022047042846679688
# [2024/11/18 20:06:20] ppocr DEBUG: cls num  : 1, elapsed : 0.009234189987182617
# [2024/11/18 20:06:20] ppocr DEBUG: rec_res num  : 1, elapsed : 0.15455937385559082
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_80d21c58a71a0751_fog.jpg
# Detected text: V8FAG
# Processed: 80d21c58a71a0751_fog.jpg
# Bounding box: {'x1': 260, 'y1': 316, 'x2': 439, 'y2': 362, 'confidence': tensor(0.8176)}
# Detected text: V8FAG
#
# 0: 640x640 1 license_plate, 77.9ms
# Speed: 3.2ms preprocess, 77.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:20] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.08538436889648438
# [2024/11/18 20:06:20] ppocr DEBUG: cls num  : 2, elapsed : 0.01572442054748535
# [2024/11/18 20:06:20] ppocr DEBUG: rec_res num  : 2, elapsed : 0.31470823287963867
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_JST2699.jpg
# Detected text: E-SALNADDE JST2699
# Processed: JST2699.jpg
# Bounding box: {'x1': 374, 'y1': 785, 'x2': 838, 'y2': 907, 'confidence': tensor(0.8643)}
# Detected text: E-SALNADDE JST2699
#
# 0: 448x640 1 license_plate, 54.2ms
# Speed: 1.9ms preprocess, 54.2ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:20] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.015404939651489258
# [2024/11/18 20:06:20] ppocr DEBUG: cls num  : 1, elapsed : 0.008279561996459961
# [2024/11/18 20:06:21] ppocr DEBUG: rec_res num  : 1, elapsed : 0.12473750114440918
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_car15_rain.jpg
# Detected text: KCS1M
# Processed: car15_rain.jpg
# Bounding box: {'x1': 136, 'y1': 186, 'x2': 260, 'y2': 236, 'confidence': tensor(0.4801)}
# Detected text: KCS1M
#
# 0: 384x640 1 license_plate, 44.3ms
# Speed: 1.9ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [2024/11/18 20:06:21] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.020064592361450195
# [2024/11/18 20:06:21] ppocr DEBUG: cls num  : 2, elapsed : 0.014241218566894531
# [2024/11/18 20:06:21] ppocr DEBUG: rec_res num  : 2, elapsed : 0.5391323566436768
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_GWT2180.jpg
# Detected text: MG-MONTES CLAROS GWT-2180
# Processed: GWT2180.jpg
# Bounding box: {'x1': 529, 'y1': 307, 'x2': 763, 'y2': 378, 'confidence': tensor(0.8625)}
# Detected text: MG-MONTES CLAROS GWT-2180
#
# 0: 640x640 1 license_plate, 85.1ms
# Speed: 2.1ms preprocess, 85.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:21] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.032846689224243164
# [2024/11/18 20:06:21] ppocr DEBUG: cls num  : 2, elapsed : 0.01473236083984375
# [2024/11/18 20:06:22] ppocr DEBUG: rec_res num  : 2, elapsed : 0.24902915954589844
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_JQV5526.jpg
# Detected text: BA-SALVADOR JQV-5526
# Processed: JQV5526.jpg
# Bounding box: {'x1': 368, 'y1': 722, 'x2': 641, 'y2': 810, 'confidence': tensor(0.9073)}
# Detected text: BA-SALVADOR JQV-5526
#
# 0: 640x640 1 license_plate, 71.1ms
# Speed: 2.2ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:22] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.015665769577026367
# [2024/11/18 20:06:22] ppocr DEBUG: cls num  : 2, elapsed : 0.014424800872802734
# [2024/11/18 20:06:22] ppocr DEBUG: rec_res num  : 2, elapsed : 0.2545888423919678
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_e79f6777f2fc08b2_jpg.rf.998e7d2e9ea4b5d8bd74e17553a16d1c_shadow.jpg
# Detected text: DUBAI 75665
# Processed: e79f6777f2fc08b2_jpg.rf.998e7d2e9ea4b5d8bd74e17553a16d1c_shadow.jpg
# Bounding box: {'x1': 159, 'y1': 267, 'x2': 283, 'y2': 317, 'confidence': tensor(0.8552)}
# Detected text: DUBAI 75665
#
# 0: 640x640 1 license_plate, 73.9ms
# Speed: 2.4ms preprocess, 73.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:22] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.05805659294128418
# [2024/11/18 20:06:22] ppocr DEBUG: cls num  : 2, elapsed : 0.015061616897583008
# [2024/11/18 20:06:22] ppocr DEBUG: rec_res num  : 2, elapsed : 0.2471940517425537
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_JSP7678.jpg
# Detected text: SSASAOOR JSP.7678
# Processed: JSP7678.jpg
# Bounding box: {'x1': 413, 'y1': 475, 'x2': 783, 'y2': 617, 'confidence': tensor(0.8534)}
# Detected text: SSASAOOR JSP.7678
#
# 0: 480x640 1 license_plate, 63.5ms
# Speed: 1.7ms preprocess, 63.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:23] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.020531415939331055
# [2024/11/18 20:06:23] ppocr DEBUG: cls num  : 1, elapsed : 0.0073451995849609375
# [2024/11/18 20:06:23] ppocr DEBUG: rec_res num  : 1, elapsed : 0.12522268295288086
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_5290f4027491d09b_shadow.jpg
# Detected text: 27-BN-42
# Processed: 5290f4027491d09b_shadow.jpg
# Bounding box: {'x1': 154, 'y1': 544, 'x2': 338, 'y2': 607, 'confidence': tensor(0.7978)}
# Detected text: 27-BN-42
#
# 0: 640x640 1 license_plate, 89.1ms
# Speed: 4.7ms preprocess, 89.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:23] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.018173933029174805
# [2024/11/18 20:06:23] ppocr DEBUG: cls num  : 1, elapsed : 0.0073316097259521484
# [2024/11/18 20:06:23] ppocr DEBUG: rec_res num  : 1, elapsed : 0.13495492935180664
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_0f4bfc46402a9f52_jpg.rf.408104f7cd2af92e7076cdb6e8102861_rain.jpg
# Detected text: CRNUK
# Processed: 0f4bfc46402a9f52_jpg.rf.408104f7cd2af92e7076cdb6e8102861_rain.jpg
# Bounding box: {'x1': 180, 'y1': 128, 'x2': 330, 'y2': 203, 'confidence': tensor(0.7513)}
# Detected text: CRNUK
#
# 0: 448x640 1 license_plate, 57.5ms
# Speed: 1.8ms preprocess, 57.5ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:23] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.011676549911499023
# [2024/11/18 20:06:23] ppocr DEBUG: cls num  : 1, elapsed : 0.013602495193481445
# [2024/11/18 20:06:23] ppocr DEBUG: rec_res num  : 1, elapsed : 0.129744291305542
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_4a1e22f4441eceb3.jpg
# Detected text: B523SNX
# Processed: 4a1e22f4441eceb3.jpg
# Bounding box: {'x1': 202, 'y1': 432, 'x2': 348, 'y2': 467, 'confidence': tensor(0.7898)}
# Detected text: B523SNX
#
# 0: 640x640 1 license_plate, 77.0ms
# Speed: 2.1ms preprocess, 77.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:23] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010039329528808594
# [2024/11/18 20:06:23] ppocr DEBUG: cls num  : 1, elapsed : 0.007618904113769531
# [2024/11/18 20:06:23] ppocr DEBUG: rec_res num  : 1, elapsed : 0.12679386138916016
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_f73b754cdb1ab677_jpg.rf.fbaf4ab9ba4b4c1149fd1339aadbbde7.jpg
# Detected text: IN2952
# Processed: f73b754cdb1ab677_jpg.rf.fbaf4ab9ba4b4c1149fd1339aadbbde7.jpg
# Bounding box: {'x1': 277, 'y1': 315, 'x2': 341, 'y2': 337, 'confidence': tensor(0.8146)}
# Detected text: IN2952
#
# 0: 480x640 1 license_plate, 53.9ms
# Speed: 2.3ms preprocess, 53.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:24] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.04908108711242676
# [2024/11/18 20:06:24] ppocr DEBUG: cls num  : 4, elapsed : 0.028099536895751953
# [2024/11/18 20:06:24] ppocr DEBUG: rec_res num  : 4, elapsed : 0.4895002841949463
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_7f9740e95a74f2b9.jpg
# Detected text: AWS 167 12 S
# Processed: 7f9740e95a74f2b9.jpg
# Bounding box: {'x1': 256, 'y1': 357, 'x2': 740, 'y2': 463, 'confidence': tensor(0.8630)}
# Detected text: AWS 167 12 S
#
# 0: 640x640 1 license_plate, 90.3ms
# Speed: 4.4ms preprocess, 90.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:24] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.028901338577270508
# [2024/11/18 20:06:24] ppocr DEBUG: cls num  : 2, elapsed : 0.014777183532714844
# [2024/11/18 20:06:25] ppocr DEBUG: rec_res num  : 2, elapsed : 0.27785491943359375
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_FZB9581.jpg
# Detected text: BA-SIMOESEILHO FBZ-9581
# Processed: FZB9581.jpg
# Bounding box: {'x1': 971, 'y1': 496, 'x2': 1227, 'y2': 577, 'confidence': tensor(0.8528)}
# Detected text: BA-SIMOESEILHO FBZ-9581
#
# 0: 480x640 1 license_plate, 49.8ms
# Speed: 1.7ms preprocess, 49.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:25] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.010440349578857422
# [2024/11/18 20:06:25] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2024/11/18 20:06:25] ppocr DEBUG: rec_res num  : 0, elapsed : 1.6689300537109375e-06
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_051_fog.jpg
# Detected text: No text detected
# Processed: test_051_fog.jpg
# Bounding box: {'x1': 98, 'y1': 228, 'x2': 200, 'y2': 256, 'confidence': tensor(0.8383)}
# Detected text: No text detected
#
# 0: 480x640 1 license_plate, 47.6ms
# Speed: 1.7ms preprocess, 47.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:25] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01985907554626465
# [2024/11/18 20:06:25] ppocr DEBUG: cls num  : 1, elapsed : 0.007546186447143555
# [2024/11/18 20:06:25] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10374116897583008
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_079ec835d9949050.jpg
# Detected text: 42:214-14
# Processed: 079ec835d9949050.jpg
# Bounding box: {'x1': 0, 'y1': 380, 'x2': 178, 'y2': 435, 'confidence': tensor(0.6954)}
# Detected text: 42:214-14
#
# 0: 448x640 1 license_plate, 42.8ms
# Speed: 1.7ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:25] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.014091253280639648
# [2024/11/18 20:06:25] ppocr DEBUG: cls num  : 1, elapsed : 0.0069828033447265625
# [2024/11/18 20:06:25] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10224771499633789
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_car15_fog.jpg
# Detected text: No text detected
# Processed: car15_fog.jpg
# Bounding box: {'x1': 86, 'y1': 182, 'x2': 258, 'y2': 239, 'confidence': tensor(0.7417)}
# Detected text: No text detected
#
# 0: 448x640 1 license_plate, 37.8ms
# Speed: 1.6ms preprocess, 37.8ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:25] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.013779640197753906
# [2024/11/18 20:06:25] ppocr DEBUG: cls num  : 1, elapsed : 0.007185220718383789
# [2024/11/18 20:06:25] ppocr DEBUG: rec_res num  : 1, elapsed : 0.09917783737182617
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_d565d93637d4e76d_rain.jpg
# Detected text: 3147HW
# Processed: d565d93637d4e76d_rain.jpg
# Bounding box: {'x1': 512, 'y1': 492, 'x2': 675, 'y2': 540, 'confidence': tensor(0.7618)}
# Detected text: 3147HW
#
# 0: 448x640 1 license_plate, 38.1ms
# Speed: 2.1ms preprocess, 38.1ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:25] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.018140792846679688
# [2024/11/18 20:06:25] ppocr DEBUG: cls num  : 1, elapsed : 0.007111787796020508
# [2024/11/18 20:06:25] ppocr DEBUG: rec_res num  : 1, elapsed : 0.09920215606689453
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_9a4fe6361597f264_rain.jpg
# Detected text: HK06 YMX
# Processed: 9a4fe6361597f264_rain.jpg
# Bounding box: {'x1': 375, 'y1': 423, 'x2': 634, 'y2': 482, 'confidence': tensor(0.8887)}
# Detected text: HK06 YMX
#
# 0: 640x640 1 license_plate, 67.0ms
# Speed: 2.1ms preprocess, 67.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:25] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.047484636306762695
# [2024/11/18 20:06:25] ppocr DEBUG: cls num  : 2, elapsed : 0.01298975944519043
# [2024/11/18 20:06:26] ppocr DEBUG: rec_res num  : 2, elapsed : 0.25479650497436523
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_PJU2207_fog.jpg
# Detected text: PJU2207
# Processed: PJU2207_fog.jpg
# Bounding box: {'x1': 418, 'y1': 916, 'x2': 821, 'y2': 1040, 'confidence': tensor(0.8972)}
# Detected text: PJU2207
#
# 0: 640x640 1 license_plate, 61.2ms
# Speed: 1.9ms preprocess, 61.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:26] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.04581046104431152
# [2024/11/18 20:06:26] ppocr DEBUG: cls num  : 2, elapsed : 0.01306295394897461
# [2024/11/18 20:06:26] ppocr DEBUG: rec_res num  : 2, elapsed : 0.2015376091003418
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_OZK4620_fog.jpg
# Detected text: RA-SALVADO OZK4620
# Processed: OZK4620_fog.jpg
# Bounding box: {'x1': 831, 'y1': 585, 'x2': 1205, 'y2': 712, 'confidence': tensor(0.8827)}
# Detected text: RA-SALVADO OZK4620
#
# 0: 576x640 1 license_plate, 65.1ms
# Speed: 2.2ms preprocess, 65.1ms inference, 0.5ms postprocess per image at shape (1, 3, 576, 640)
# [2024/11/18 20:06:26] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.009163141250610352
# [2024/11/18 20:06:26] ppocr DEBUG: cls num  : 1, elapsed : 0.008833646774291992
# [2024/11/18 20:06:26] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10566473007202148
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_025.jpg
# Detected text: RK896A0
# Processed: test_025.jpg
# Bounding box: {'x1': 155, 'y1': 209, 'x2': 282, 'y2': 237, 'confidence': tensor(0.8525)}
# Detected text: RK896A0
#
# 0: 448x640 1 license_plate, 41.2ms
# Speed: 2.0ms preprocess, 41.2ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:26] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03333568572998047
# [2024/11/18 20:06:26] ppocr DEBUG: cls num  : 2, elapsed : 0.012701034545898438
# [2024/11/18 20:06:27] ppocr DEBUG: rec_res num  : 2, elapsed : 0.19036221504211426
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_1ca1155083156d72_fog.jpg
# Detected text: OUTSTDN
# Processed: 1ca1155083156d72_fog.jpg
# Bounding box: {'x1': 362, 'y1': 378, 'x2': 653, 'y2': 501, 'confidence': tensor(0.9293)}
# Detected text: OUTSTDN
#
# 0: 640x640 1 license_plate, 75.8ms
# Speed: 2.0ms preprocess, 75.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:27] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01281881332397461
# [2024/11/18 20:06:27] ppocr DEBUG: cls num  : 1, elapsed : 0.007998228073120117
# [2024/11/18 20:06:27] ppocr DEBUG: rec_res num  : 1, elapsed : 0.11828184127807617
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_80e02a518ffe4cb2_jpg.rf.f8e889ac521be67cbdd6cdb84ecdd52d_fog.jpg
# Detected text: B81JKY
# Processed: 80e02a518ffe4cb2_jpg.rf.f8e889ac521be67cbdd6cdb84ecdd52d_fog.jpg
# Bounding box: {'x1': 151, 'y1': 234, 'x2': 274, 'y2': 275, 'confidence': tensor(0.8477)}
# Detected text: B81JKY
#
# 0: 384x640 1 license_plate, 38.6ms
# Speed: 1.5ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# [2024/11/18 20:06:27] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.009389162063598633
# [2024/11/18 20:06:27] ppocr DEBUG: cls num  : 1, elapsed : 0.008249282836914062
# [2024/11/18 20:06:27] ppocr DEBUG: rec_res num  : 1, elapsed : 0.1111142635345459
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_010a0c44af2d077e.jpg
# Detected text: AV-147-VZ
# Processed: 010a0c44af2d077e.jpg
# Bounding box: {'x1': 742, 'y1': 357, 'x2': 877, 'y2': 403, 'confidence': tensor(0.5261)}
# Detected text: AV-147-VZ
#
# 0: 480x640 1 license_plate, 46.5ms
# Speed: 1.6ms preprocess, 46.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:27] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.009242057800292969
# [2024/11/18 20:06:27] ppocr DEBUG: cls num  : 1, elapsed : 0.008583545684814453
# [2024/11/18 20:06:27] ppocr DEBUG: rec_res num  : 1, elapsed : 0.1265859603881836
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_072.jpg
# Detected text: 4839376
# Processed: test_072.jpg
# Bounding box: {'x1': 100, 'y1': 137, 'x2': 199, 'y2': 160, 'confidence': tensor(0.8480)}
# Detected text: 4839376
#
# 0: 384x640 1 license_plate, 36.4ms
# Speed: 1.4ms preprocess, 36.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [2024/11/18 20:06:27] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.019440174102783203
# [2024/11/18 20:06:27] ppocr DEBUG: cls num  : 2, elapsed : 0.012907266616821289
# [2024/11/18 20:06:28] ppocr DEBUG: rec_res num  : 2, elapsed : 0.2663578987121582
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_OUZ2198.jpg
# Detected text: BASALYADOR OUZ-2198
# Processed: OUZ2198.jpg
# Bounding box: {'x1': 476, 'y1': 453, 'x2': 713, 'y2': 526, 'confidence': tensor(0.8591)}
# Detected text: BASALYADOR OUZ-2198
#
# 0: 640x640 1 license_plate, 62.2ms
# Speed: 1.9ms preprocess, 62.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.008661031723022461
# [2024/11/18 20:06:28] ppocr DEBUG: cls num  : 1, elapsed : 0.006829023361206055
# [2024/11/18 20:06:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.0983896255493164
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_b6ecda23586a6ba5_jpg.rf.d737139968dd3f08447305aa7b7f6002_shadow.jpg
# Detected text: BEHM 927
# Processed: b6ecda23586a6ba5_jpg.rf.d737139968dd3f08447305aa7b7f6002_shadow.jpg
# Bounding box: {'x1': 119, 'y1': 307, 'x2': 168, 'y2': 356, 'confidence': tensor(0.7779)}
# Detected text: BEHM 927
#
# 0: 320x640 1 license_plate, 34.5ms
# Speed: 1.5ms preprocess, 34.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# [2024/11/18 20:06:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0092926025390625
# [2024/11/18 20:06:28] ppocr DEBUG: cls num  : 1, elapsed : 0.007676124572753906
# [2024/11/18 20:06:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10563015937805176
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_03fe4b804d6f46c6.jpg
# Detected text: DGS3250
# Processed: 03fe4b804d6f46c6.jpg
# Bounding box: {'x1': 797, 'y1': 216, 'x2': 910, 'y2': 258, 'confidence': tensor(0.6808)}
# Detected text: DGS3250
#
# 0: 384x640 1 license_plate, 38.9ms
# Speed: 1.6ms preprocess, 38.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# [2024/11/18 20:06:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.017993688583374023
# [2024/11/18 20:06:28] ppocr DEBUG: cls num  : 1, elapsed : 0.0076329708099365234
# [2024/11/18 20:06:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.1020359992980957
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_dec4608715b2d28d_rain.jpg
# Detected text: 31:000-00
# Processed: dec4608715b2d28d_rain.jpg
# Bounding box: {'x1': 191, 'y1': 427, 'x2': 428, 'y2': 491, 'confidence': tensor(0.7689)}
# Detected text: 31:000-00
#
# 0: 448x640 1 license_plate, 44.7ms
# Speed: 2.7ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.009980916976928711
# [2024/11/18 20:06:28] ppocr DEBUG: cls num  : 1, elapsed : 0.007540702819824219
# [2024/11/18 20:06:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10623908042907715
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_7fc0fb6035bc06a6_rain.jpg
# Detected text: BW5701
# Processed: 7fc0fb6035bc06a6_rain.jpg
# Bounding box: {'x1': 404, 'y1': 518, 'x2': 562, 'y2': 558, 'confidence': tensor(0.8160)}
# Detected text: BW5701
#
# 0: 544x640 1 license_plate, 68.6ms
# Speed: 1.6ms preprocess, 68.6ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
# [2024/11/18 20:06:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.008486509323120117
# [2024/11/18 20:06:28] ppocr DEBUG: cls num  : 1, elapsed : 0.007864952087402344
# [2024/11/18 20:06:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10036253929138184
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_031.jpg
# Detected text: RK-619AS
# Processed: test_031.jpg
# Bounding box: {'x1': 186, 'y1': 170, 'x2': 292, 'y2': 194, 'confidence': tensor(0.8994)}
# Detected text: RK-619AS
#
# 0: 448x640 1 license_plate, 50.7ms
# Speed: 1.9ms preprocess, 50.7ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:29] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.012462377548217773
# [2024/11/18 20:06:29] ppocr DEBUG: cls num  : 2, elapsed : 0.012997150421142578
# [2024/11/18 20:06:29] ppocr DEBUG: rec_res num  : 2, elapsed : 0.20000028610229492
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_fde614fa6023dd03.jpg
# Detected text: New F71CCV
# Processed: fde614fa6023dd03.jpg
# Bounding box: {'x1': 469, 'y1': 293, 'x2': 595, 'y2': 354, 'confidence': tensor(0.8145)}
# Detected text: New F71CCV
#
# 0: 640x640 1 license_plate, 75.1ms
# Speed: 1.9ms preprocess, 75.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.00872802734375
# [2024/11/18 20:06:29] ppocr DEBUG: cls num  : 1, elapsed : 0.008841753005981445
# [2024/11/18 20:06:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10548877716064453
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_c7df5232291486a3_jpg.rf.d18b52a383576cfe6c4ec343fca07a80.jpg
# Detected text: WM64UMA
# Processed: c7df5232291486a3_jpg.rf.d18b52a383576cfe6c4ec343fca07a80.jpg
# Bounding box: {'x1': 243, 'y1': 255, 'x2': 347, 'y2': 291, 'confidence': tensor(0.8243)}
# Detected text: WM64UMA
#
# ...
# [2024/11/18 20:06:33] ppocr DEBUG: cls num  : 1, elapsed : 0.008791208267211914
# [2024/11/18 20:06:33] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10711836814880371
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_70e7b5173fe1e289_fog.jpg
# Detected text: HKIONYY
# Processed: 70e7b5173fe1e289_fog.jpg
# Bounding box: {'x1': 173, 'y1': 239, 'x2': 445, 'y2': 325, 'confidence': tensor(0.8526)}
# Detected text: HKIONYY
#
# 0: 480x640 1 license_plate, 50.2ms
# Speed: 1.7ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:33] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.008991241455078125
# [2024/11/18 20:06:33] ppocr DEBUG: cls num  : 1, elapsed : 0.007651329040527344
# [2024/11/18 20:06:33] ppocr DEBUG: rec_res num  : 1, elapsed : 0.11092734336853027
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_037_shadow.jpg
# Detected text: RK-260AR
# Processed: test_037_shadow.jpg
# Bounding box: {'x1': 314, 'y1': 225, 'x2': 411, 'y2': 248, 'confidence': tensor(0.7930)}
# Detected text: RK-260AR
#
# 0: 640x640 1 license_plate, 76.7ms
# Speed: 2.8ms preprocess, 76.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:33] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.030076265335083008
# [2024/11/18 20:06:33] ppocr DEBUG: cls num  : 1, elapsed : 0.008603811264038086
# [2024/11/18 20:06:33] ppocr DEBUG: rec_res num  : 1, elapsed : 0.11295390129089355
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_c7df5232291486a3_fog.jpg
# Detected text: WM64UMA
# Processed: c7df5232291486a3_fog.jpg
# Bounding box: {'x1': 601, 'y1': 626, 'x2': 854, 'y2': 715, 'confidence': tensor(0.8311)}
# Detected text: WM64UMA
#
# 0: 640x640 1 license_plate, 65.2ms
# Speed: 2.4ms preprocess, 65.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:34] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.049051523208618164
# [2024/11/18 20:06:34] ppocr DEBUG: cls num  : 2, elapsed : 0.013639688491821289
# [2024/11/18 20:06:34] ppocr DEBUG: rec_res num  : 2, elapsed : 0.21125054359436035
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_PJP2783.jpg
# Detected text: BA-SALVADOR PJP-2783
# Processed: PJP2783.jpg
# Bounding box: {'x1': 426, 'y1': 816, 'x2': 821, 'y2': 938, 'confidence': tensor(0.8859)}
# Detected text: BA-SALVADOR PJP-2783
#
# 0: 640x640 1 license_plate, 63.7ms
# Speed: 2.6ms preprocess, 63.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:34] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.025058507919311523
# [2024/11/18 20:06:34] ppocr DEBUG: cls num  : 1, elapsed : 0.007073163986206055
# [2024/11/18 20:06:34] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10951495170593262
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_NZJ6581_fog.jpg
# Detected text: NZJ-6581
# Processed: NZJ6581_fog.jpg
# Bounding box: {'x1': 514, 'y1': 775, 'x2': 772, 'y2': 856, 'confidence': tensor(0.8199)}
# Detected text: NZJ-6581
#
# 0: 640x544 1 license_plate, 54.0ms
# Speed: 2.5ms preprocess, 54.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 544)
# [2024/11/18 20:06:34] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01674675941467285
# [2024/11/18 20:06:34] ppocr DEBUG: cls num  : 1, elapsed : 0.007264375686645508
# [2024/11/18 20:06:34] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10376095771789551
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_ee903b2cbad00eb3.jpg
# Detected text: KAKAO. LV
# Processed: ee903b2cbad00eb3.jpg
# Bounding box: {'x1': 317, 'y1': 765, 'x2': 533, 'y2': 814, 'confidence': tensor(0.8564)}
# Detected text: KAKAO. LV
#
# 0: 512x640 1 license_plate, 55.8ms
# Speed: 1.6ms preprocess, 55.8ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
# [2024/11/18 20:06:34] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.008966207504272461
# [2024/11/18 20:06:34] ppocr DEBUG: cls num  : 1, elapsed : 0.0076105594635009766
# [2024/11/18 20:06:34] ppocr DEBUG: rec_res num  : 1, elapsed : 0.11345624923706055
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_013.jpg
# Detected text: RK-857AI
# Processed: test_013.jpg
# Bounding box: {'x1': 130, 'y1': 147, 'x2': 243, 'y2': 172, 'confidence': tensor(0.8758)}
# Detected text: RK-857AI
#
# 0: 448x640 1 license_plate, 56.4ms
# Speed: 3.3ms preprocess, 56.4ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:34] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.017086029052734375
# [2024/11/18 20:06:34] ppocr DEBUG: cls num  : 1, elapsed : 0.0070645809173583984
# [2024/11/18 20:06:35] ppocr DEBUG: rec_res num  : 1, elapsed : 0.11287951469421387
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_44df21d6584b44a3.jpg
# Detected text: G237OHR
# Processed: 44df21d6584b44a3.jpg
# Bounding box: {'x1': 639, 'y1': 359, 'x2': 796, 'y2': 410, 'confidence': tensor(0.7786)}
# Detected text: G237OHR
#
# 0: 544x640 1 license_plate, 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 0.8ms postprocess per image at shape (1, 3, 544, 640)
# [2024/11/18 20:06:35] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.014997482299804688
# [2024/11/18 20:06:35] ppocr DEBUG: cls num  : 1, elapsed : 0.007871866226196289
# [2024/11/18 20:06:35] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10684919357299805
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_022_shadow.jpg
# Detected text: RK875AE
# Processed: test_022_shadow.jpg
# Bounding box: {'x1': 185, 'y1': 260, 'x2': 310, 'y2': 288, 'confidence': tensor(0.9082)}
# Detected text: RK875AE
#
# 0: 512x640 1 license_plate, 51.0ms
# Speed: 2.1ms preprocess, 51.0ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
# [2024/11/18 20:06:35] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.007017612457275391
# [2024/11/18 20:06:35] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2024/11/18 20:06:35] ppocr DEBUG: rec_res num  : 0, elapsed : 1.9073486328125e-06
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_018_fog.jpg
# Detected text: No text detected
# Processed: test_018_fog.jpg
# Bounding box: {'x1': 131, 'y1': 164, 'x2': 208, 'y2': 182, 'confidence': tensor(0.8097)}
# Detected text: No text detected
#
# 0: 480x640 1 license_plate, 48.9ms
# Speed: 1.9ms preprocess, 48.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:35] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.022198915481567383
# [2024/11/18 20:06:35] ppocr DEBUG: cls num  : 1, elapsed : 0.010319709777832031
# [2024/11/18 20:06:35] ppocr DEBUG: rec_res num  : 1, elapsed : 0.11261177062988281
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_d5058059dc0ce0ad_rain.jpg
# Detected text: AURA 1
# Processed: d5058059dc0ce0ad_rain.jpg
# Bounding box: {'x1': 451, 'y1': 395, 'x2': 656, 'y2': 459, 'confidence': tensor(0.8538)}
# Detected text: AURA 1
#
# 0: 480x640 1 license_plate, 50.1ms
# Speed: 1.7ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:35] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.00875711441040039
# [2024/11/18 20:06:35] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2024/11/18 20:06:35] ppocr DEBUG: rec_res num  : 0, elapsed : 1.1920928955078125e-06
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_012_fog.jpg
# Detected text: No text detected
# Processed: test_012_fog.jpg
# Bounding box: {'x1': 249, 'y1': 256, 'x2': 374, 'y2': 287, 'confidence': tensor(0.8702)}
# Detected text: No text detected
#
# 0: 448x640 1 license_plate, 45.2ms
# Speed: 2.1ms preprocess, 45.2ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:35] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.009111642837524414
# [2024/11/18 20:06:35] ppocr DEBUG: cls num  : 1, elapsed : 0.007829427719116211
# [2024/11/18 20:06:35] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10951519012451172
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_11f80fda2c38011c.jpg
# Detected text: 990XWK
# Processed: 11f80fda2c38011c.jpg
# Bounding box: {'x1': 543, 'y1': 454, 'x2': 650, 'y2': 495, 'confidence': tensor(0.6757)}
# Detected text: 990XWK
#
# 0: 640x640 1 license_plate, 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:35] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.012684345245361328
# [2024/11/18 20:06:35] ppocr DEBUG: cls num  : 1, elapsed : 0.012603282928466797
# [2024/11/18 20:06:36] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10608792304992676
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_fdd963edc28bf163_jpg.rf.0ceca3ffee4d2cedea59ed66b5fce75f_rain.jpg
# Detected text: TL 03GOG
# Processed: fdd963edc28bf163_jpg.rf.0ceca3ffee4d2cedea59ed66b5fce75f_rain.jpg
# Bounding box: {'x1': 190, 'y1': 198, 'x2': 328, 'y2': 250, 'confidence': tensor(0.8711)}
# Detected text: TL 03GOG
#
# 0: 640x640 1 license_plate, 62.4ms
# Speed: 4.5ms preprocess, 62.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:36] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.03098583221435547
# [2024/11/18 20:06:36] ppocr DEBUG: cls num  : 2, elapsed : 0.014887332916259766
# [2024/11/18 20:06:36] ppocr DEBUG: rec_res num  : 2, elapsed : 0.27285265922546387
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_JSK5419.jpg
# Detected text: A-SALYADOR JSK5419
# Processed: JSK5419.jpg
# Bounding box: {'x1': 496, 'y1': 606, 'x2': 839, 'y2': 707, 'confidence': tensor(0.8739)}
# Detected text: A-SALYADOR JSK5419
#
# 0: 512x640 1 license_plate, 50.5ms
# Speed: 1.8ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
# [2024/11/18 20:06:36] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.017611026763916016
# [2024/11/18 20:06:36] ppocr DEBUG: cls num  : 1, elapsed : 0.011738061904907227
# [2024/11/18 20:06:36] ppocr DEBUG: rec_res num  : 1, elapsed : 0.1025552749633789
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_cddeaa7666940862_shadow.jpg
# Detected text: 53:33335
# Processed: cddeaa7666940862_shadow.jpg
# Bounding box: {'x1': 290, 'y1': 591, 'x2': 511, 'y2': 654, 'confidence': tensor(0.8397)}
# Detected text: 53:33335
#
# 0: 384x640 1 license_plate, 43.9ms
# Speed: 2.1ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# [2024/11/18 20:06:36] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.012478113174438477
# [2024/11/18 20:06:36] ppocr DEBUG: cls num  : 1, elapsed : 0.006761074066162109
# [2024/11/18 20:06:36] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10210299491882324
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_437f13cba48646c3.jpg
# Detected text: T44RCN
# Processed: 437f13cba48646c3.jpg
# Bounding box: {'x1': 556, 'y1': 198, 'x2': 679, 'y2': 246, 'confidence': tensor(0.7023)}
# Detected text: T44RCN
#
# 0: 480x640 1 license_plate, 43.5ms
# Speed: 2.5ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:36] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.03702068328857422
# [2024/11/18 20:06:36] ppocr DEBUG: cls num  : 1, elapsed : 0.008240461349487305
# [2024/11/18 20:06:37] ppocr DEBUG: rec_res num  : 1, elapsed : 0.12054729461669922
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_66a8a43a717eb459_shadow.jpg
# Detected text: 02093BU
# Processed: 66a8a43a717eb459_shadow.jpg
# Bounding box: {'x1': 363, 'y1': 398, 'x2': 751, 'y2': 494, 'confidence': tensor(0.8404)}
# Detected text: 02093BU
#
# 0: 640x640 2 license_plates, 72.6ms
# Speed: 3.7ms preprocess, 72.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:37] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.020454883575439453
# [2024/11/18 20:06:37] ppocr DEBUG: cls num  : 1, elapsed : 0.009971141815185547
# [2024/11/18 20:06:37] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10336542129516602
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_PJJ1406.jpg
# Detected text: PJJ1406
# Processed: PJJ1406.jpg
# Bounding box: {'x1': 483, 'y1': 593, 'x2': 725, 'y2': 668, 'confidence': tensor(0.8732)}
# Detected text: PJJ1406
#
# 0: 448x640 1 license_plate, 39.6ms
# Speed: 1.8ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# [2024/11/18 20:06:37] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0311281681060791
# [2024/11/18 20:06:37] ppocr DEBUG: cls num  : 1, elapsed : 0.007410526275634766
# [2024/11/18 20:06:37] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10752606391906738
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_2799cab694b8824b.jpg
# Detected text: AB 577
# Processed: 2799cab694b8824b.jpg
# Bounding box: {'x1': 309, 'y1': 345, 'x2': 702, 'y2': 426, 'confidence': tensor(0.9062)}
# Detected text: AB 577
#
# 0: 640x480 1 license_plate, 64.1ms
# Speed: 3.4ms preprocess, 64.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# [2024/11/18 20:06:37] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.020051956176757812
# [2024/11/18 20:06:37] ppocr DEBUG: cls num  : 1, elapsed : 0.007457256317138672
# [2024/11/18 20:06:37] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10796618461608887
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_1071b237587a698b.jpg
# Detected text: NoHZ 1002
# Processed: 1071b237587a698b.jpg
# Bounding box: {'x1': 246, 'y1': 677, 'x2': 489, 'y2': 736, 'confidence': tensor(0.8331)}
# Detected text: NoHZ 1002
#
# 0: 480x640 1 license_plate, 55.2ms
# Speed: 1.4ms preprocess, 55.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# [2024/11/18 20:06:37] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.009164094924926758
# [2024/11/18 20:06:37] ppocr DEBUG: cls num  : 1, elapsed : 0.007907867431640625
# [2024/11/18 20:06:37] ppocr DEBUG: rec_res num  : 1, elapsed : 0.11076664924621582
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_test_077.jpg
# Detected text: RK-735AS
# Processed: test_077.jpg
# Bounding box: {'x1': 176, 'y1': 227, 'x2': 285, 'y2': 251, 'confidence': tensor(0.8684)}
# Detected text: RK-735AS
#
# 0: 640x640 1 license_plate, 65.4ms
# Speed: 1.9ms preprocess, 65.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# [2024/11/18 20:06:38] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.008823394775390625
# [2024/11/18 20:06:38] ppocr DEBUG: cls num  : 1, elapsed : 0.007122516632080078
# [2024/11/18 20:06:38] ppocr DEBUG: rec_res num  : 1, elapsed : 0.1058955192565918
# Annotated image saved at /media/asmany/e054e025-4de0-482e-bf54-4fb67a1e5566/Hof University/AI Project/OCR test image/annotated_ccc1a2d44a290368_jpg.rf.8e8d6f87f1d1327caf5f80e0c96cdad9_rain.jpg
# Detected text: C26727
# Processed: ccc1a2d44a290368_jpg.rf.8e8d6f87f1d1327caf5f80e0c96cdad9_rain.jpg
# Bounding box: {'x1': 208, 'y1': 255, 'x2': 264, 'y2': 295, 'confidence': tensor(0.8860)}
# Detected text: C26727
